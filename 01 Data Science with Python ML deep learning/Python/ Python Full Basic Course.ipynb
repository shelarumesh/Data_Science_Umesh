# %% [markdown]
# # Python Full Basic Course

# %% [markdown]
# # Data Tyeps In Python

# %% [markdown]
# 1. Int
# 2. Float
# 3. Str
# 4. Date Time
# 5. List
# 6. Tuple
# 7. Set
# 8. Dictionry

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
b=22.4

# %%
type(b)
# Out:
# float
