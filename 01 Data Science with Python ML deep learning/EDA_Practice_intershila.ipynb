# %%
import pandas as pd
import numpy as np

# %%
path='/content/drive/MyDrive/Python/Dataset/1. Regression - Module - (Housing Prices).csv'
df=pd.read_csv(path)

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
df['Sale Price'].head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: Sale Price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %% [markdown]
# Read data and undurstand the values

# %%
df.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %% [markdown]
# undustand graphical and its insight

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['ID'],df['Sale Price'])

# %% [markdown]
# some data points are see as outlier which is above 6

# %%
q1=df['Sale Price'].quantile(0.25)
q3=df['Sale Price'].quantile(0.75)
iqr=q3-q1
iqr
# Out:
# 323050.0

# %%
lower_limit = q1-(1.5*iqr)
lower_limit
# Out:
# -162625.0

# %%
upper_limit = q3+(1.5*iqr)
upper_limit
# Out:
# 1129575.0

# %%
l_limit=min(df['Sale Price'])
l_limit
# Out:
# 75000.0

# %% [markdown]
# lower limit is re define because not matching

# %%
plt.hist(df['Sale Price'], bins=10, color='green')
# Out:
# (array([1.9017e+04, 2.1420e+03, 3.2200e+02, 9.0000e+01, 2.6000e+01,
#         4.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  75000.,  837500., 1600000., 2362500., 3125000., 3887500.,
#         4650000., 5412500., 6175000., 6937500., 7700000.]),
#  <BarContainer object of 10 artists>)

# %%
#outlier = bet lower and upper limit of data

# %%
def limit_imputer(value):
  if value > upper_limit:
    return upper_limit
  if value < l_limit:
    return l_limit
  else :
    return value

# %%
df['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %%
df['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %%
df['Sale Price'] = df['Sale Price'].apply(limit_imputer)
df['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %% [markdown]
# from above data some entry are missing.
#
#
# *   deleting
# *   imputing

# %%
df.dropna(inplace=True, axis=0, subset=['Sale Price'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
plt.hist(df['Sale Price'], bins=10, color='green')
# Out:
# (array([ 501., 3379., 4513., 3911., 3069., 1977., 1432.,  877.,  531.,
#         1419.]),
#  array([  75000. ,  180457.5,  285915. ,  391372.5,  496830. ,  602287.5,
#          707745. ,  813202.5,  918660. , 1024117.5, 1129575. ]),
#  <BarContainer object of 10 artists>)

# %%
df['Sale Price']
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: Sale Price, Length: 21609, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# No of Times Visited                          0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# ...

# %%
df['No of Bathrooms']=df['No of Bathrooms'].mean()
df['Flat Area (in Sqft)']=df['Flat Area (in Sqft)'].mean()
df['Lot Area (in Sqft)']=df['Lot Area (in Sqft)'].mean()
df['Area of the House from Basement (in Sqft)']=df['Area of the House from Basement (in Sqft)'].mean()
df['Zipcode']=df['Zipcode'].mean()
df['Living Area after Renovation (in Sqft)']=df['Living Area after Renovation (in Sqft)'].mean()
df['Latitude']=df['Latitude'].mean()
df['Longitude']=df['Longitude'].mean()

# %%
df.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# No of Times Visited                          0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# ...

# %%
df['Zipcode'] = df['Zipcode'].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
df['No of Times Visited'].unique()
# Out:
# array(['None', 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
maping ={'None':0, 'Thrice':2, 'Four':4, 'Twice':2, 'Once':1}

# %%
df['No of Times Visited']=df['No of Times Visited'].map(maping)

# %%
df['No of Times Visited'].unique()
# Out:
# array([0, 2, 4, 1])

# %% [markdown]
# combine or slit variable

# %%
import numpy as np

# %%
df['renovated_year'] = np.where(df['Renovated Year'] == 0, 'No' , 'Yes')

# %%
df.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3         2.114684
# 1  6414100192    538000.0               3         2.114684
# 2  5631500400    180000.0               2         2.114684
# 3  2487200875    604000.0               4         2.114684
# 4  1954400510    510000.0               3         2.114684
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0          2079.943333        15109.526759           1.0              No
# 1          2079.943333        15109.526759           2.0              No
# 2          2079.943333        15109.526759           1.0              No
# 3          2079.943333        15109.526759           1.0              No
# 4          2079.943333        15109.526759           1.0              No
#
#    No of Times Visited Condition of the House  ...  \
# 0                    0                   Fair  ...
# 1                    0                   Fair  ...
# ...

# %%
df['purchase_year']=pd.DatetimeIndex(df['Date House was Sold']).year

# %%
df['years_of_renovation'] = np.where(df['renovated_year'] == 'Yes', abs(df['purchase_year']-df['Renovated Year']),0)

# %%
df.drop(columns = ['Date House was Sold','Renovated Year','purchase_year'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Sale Price                                 21609 non-null  float64
#  2   No of Bedrooms                             21609 non-null  int64
#  3   No of Bathrooms                            21609 non-null  float64
#  4   Flat Area (in Sqft)                        21609 non-null  float64
#  5   Lot Area (in Sqft)                         21609 non-null  float64
#  6   No of Floors                               21609 non-null  float64
#  7   Waterfront View                            21609 non-null  object
#  8   No of Times Visited                        21609 non-null  int64
#  9   Condition of the House                     21609 non-null  object
# ...

# %%
df['Sale Price'].corr(df['Flat Area (in Sqft)'])
# Out:
# nan

# %%
plt.scatter(df['Sale Price'],df['Flat Area (in Sqft)'])

# %%
np.corrcoef(df['Sale Price'],df['Flat Area (in Sqft)'])
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# array([[ 1., nan],
#        [nan, nan]])

# %%
df.drop(columns=['ID']).corr()
# Out:
# <ipython-input-103-3703d291d2b6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.drop(columns=['ID']).corr()
#                                            Sale Price  No of Bedrooms  \
# Sale Price                                   1.000000        0.339407
# No of Bedrooms                               0.339407        1.000000
# No of Bathrooms                                   NaN             NaN
# Flat Area (in Sqft)                               NaN             NaN
# Lot Area (in Sqft)                                NaN             NaN
# No of Floors                                 0.298913        0.175536
# No of Times Visited                          0.353556        0.076982
# Overall Grade                                0.680914        0.349223
# ...
