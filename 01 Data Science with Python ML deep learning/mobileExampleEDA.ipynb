# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/Python/Dataset/cleaned_all_phones.csv')

# %%
df.head()
# Out:
#        phone_name   brand           os  inches resolution  battery  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0   720x1280     2200
# 1        K20 plus      LG  Android 7.0     5.3   720x1280     2700
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2  1080x1920     3000
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5  1080x1920     4100
# 4             P10  Huawei  Android 7.0     5.1  1080x1920     3200
#
#   battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 0        Li-Po        2        2016-09-01      140.0  ...        False
# 1       Li-Ion        2        2016-12-01      140.0  ...         True
# 2       Li-Ion        4        2017-01-01      147.0  ...         True
# 3        Li-Po        4        2017-01-01      165.0  ...         True
# 4       Li-Ion        4        2017-02-01      145.0  ...         True
#
#    video_4K  video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# ...

# %%
df.tail()
# Out:
#             phone_name   brand          os  inches resolution  battery  \
# 1507         vivo Y77t    Vivo  Android 13    6.64  1080x2388     5000
# 1508               11x  Realme  Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme  Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme  Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo  Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 1507        Li-Po        8        2023-08-18      190.0  ...         True
# 1508        Li-Po        8        2023-08-23      190.0  ...         True
# 1509        Li-Po       16        2023-08-28      205.0  ...         True
# 1510        Li-Po       24        2023-08-28      205.0  ...         True
# 1511        Li-Po        8        2023-08-31      175.0  ...         True
#
#       video_4K  video_8K  video_30fps  video_60fps  video_120fps  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %%
df.dtypes
# Out:
# phone_name            object
# brand                 object
# os                    object
# inches               float64
# resolution            object
# battery                int64
# battery_type          object
# ram(GB)                int64
# announcement_date     object
# weight(g)            float64
# storage(GB)            int64
# video_720p              bool
# video_1080p             bool
# video_4K                bool
# video_8K                bool
# video_30fps             bool
# video_60fps             bool
# video_120fps            bool
# video_240fps            bool
# video_480fps            bool
# video_960fps            bool
# price(USD)           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['phone_name', 'brand', 'os', 'inches', 'resolution', 'battery',
#        'battery_type', 'ram(GB)', 'announcement_date', 'weight(g)',
#        'storage(GB)', 'video_720p', 'video_1080p', 'video_4K', 'video_8K',
#        'video_30fps', 'video_60fps', 'video_120fps', 'video_240fps',
#        'video_480fps', 'video_960fps', 'price(USD)'],
#       dtype='object')

# %%
df.describe()
# Out:
#             inches      battery      ram(GB)    weight(g)  storage(GB)  \
# count  1512.000000  1512.000000  1512.000000  1512.000000  1512.000000
# mean      6.422460  4389.798942     6.683862   187.636243   109.164683
# std       0.477043   784.607022     2.701433    26.200115    74.436484
# min       3.800000  1821.000000     1.000000   130.000000     1.000000
# 25%       6.300000  4000.000000     4.000000   175.000000    64.000000
# 50%       6.500000  4500.000000     8.000000   187.000000   128.000000
# 75%       6.670000  5000.000000     8.000000   197.250000   128.000000
# max      10.400000  7250.000000    24.000000   500.000000   512.000000
#
#         price(USD)
# count  1512.000000
# mean    337.847036
# std     266.740821
# min      40.000000
# 25%     179.997500
# 50%     260.000000
# 75%     400.000000
# max    2300.000000

# %%
df.describe(include='all')
# Out:
#        phone_name   brand          os       inches resolution      battery  \
# count        1512    1512        1512  1512.000000       1512  1512.000000
# unique       1496      13          34          NaN         85          NaN
# top           V30  Xiaomi  Android 11          NaN  1080x2400          NaN
# freq            3     264         322          NaN        437          NaN
# mean          NaN     NaN         NaN     6.422460        NaN  4389.798942
# std           NaN     NaN         NaN     0.477043        NaN   784.607022
# min           NaN     NaN         NaN     3.800000        NaN  1821.000000
# 25%           NaN     NaN         NaN     6.300000        NaN  4000.000000
# 50%           NaN     NaN         NaN     6.500000        NaN  4500.000000
# 75%           NaN     NaN         NaN     6.670000        NaN  5000.000000
# max           NaN     NaN         NaN    10.400000        NaN  7250.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %%
df['price(USD)'].mean()
# Out:
# 337.8470357142857

# %%
df['price(USD)'].min()
# Out:
# 40.0

# %%
df['price(USD)'].max()
# Out:
# 2300.0

# %%
df['price(USD)'].std()
# Out:
# 266.74082133237664

# %%
df['price(USD)'].std()
# Out:
# 266.74082133237664

# %%
df['price(USD)'].quantile(0.25)
# Out:
# 179.9975

# %%
df.columns
# Out:
# Index(['phone_name', 'brand', 'os', 'inches', 'resolution', 'battery',
#        'battery_type', 'ram(GB)', 'announcement_date', 'weight(g)',
#        'storage(GB)', 'video_720p', 'video_1080p', 'video_4K', 'video_8K',
#        'video_30fps', 'video_60fps', 'video_120fps', 'video_240fps',
#        'video_480fps', 'video_960fps', 'price(USD)'],
#       dtype='object')

# %%
df['brand'].unique()
# Out:
# array(['Huawei', 'LG', 'Xiaomi', 'Sony', 'Oppo', 'Samsung', 'Lenovo',
#        'Apple', 'Google', 'Honor', 'Realme', 'OnePlus', 'Vivo'],
#       dtype=object)

# %% [markdown]
# Standard Deviation and difference of calculation by pandas and numpy

# %%
import numpy as np

# %%
a=np.std(df['price(USD)'])
a
# Out:
# 266.65259879934257

# %%
b=df['price(USD)'].std()
b
# Out:
# 266.74082133237664

# %%
b-a
# Out:
# 0.08822253303407024

# %%
np.std(df['price(USD)'],ddof=1)
# Out:
# 266.74082133237664

# %%
np.std(df['price(USD)'],ddof=1) == b
# Out:
# True

# %%
#dir(np)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['price(USD)'],color='green')
plt.xlabel('Price of mobile')
plt.ylabel('Price of mobile')
plt.title('Price of mobile')
# Out:
# Text(0.5, 1.0, 'Price of mobile')

# %%
plt.plot(df['price(USD)'],color='green',marker='o', markerfacecolor='Blue')
plt.xlabel('Price of mobile')
plt.ylabel('Price of mobile')
plt.title('Price of mobile')
# Out:
# Text(0.5, 1.0, 'Price of mobile')

# %%
df['brand'].value_counts()
# Out:
# Xiaomi     264
# Oppo       213
# Samsung    206
# Vivo       168
# Realme     157
# Huawei     137
# Honor      124
# LG          75
# OnePlus     47
# Lenovo      43
# Sony        37
# Apple       22
# Google      19
# Name: brand, dtype: int64

# %%
plt.pie(df['brand'].value_counts(),labels=df['brand'].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x7e2ba9cc1f30>,
# ...
#  [Text(0.938619961697403, 0.5735787369691854, '264'),
#   Text(0.034277675445903544, 1.0994657979973845, '213'),
#   Text(-0.8186816639961472, 0.7346838320233403, '206'),
#   Text(-1.098850975521467, -0.05026463563501026, '168'),
#   Text(-0.8262698326320352, -0.7261392178378941, '157'),
#   Text(-0.2603442915703464, -1.0687473274103354, '137'),
#   Text(0.32859591282233475, -1.0497736546877412, '124'),
#   Text(0.7226993399050612, -0.8292802084342716, '75'),
#   Text(0.9075732071001918, -0.6215391168332628, '47'),
#   Text(1.0073023416728644, -0.4419751038920227, '43'),
#   Text(1.0665466948837843, -0.2692176584707552, '37'),
#   Text(1.0914631298773063, -0.1367780542281352, '22'),
#   Text(1.0991429439328266, -0.04341415440474845, '19')])

# %%
df.columns
# Out:
# Index(['phone_name', 'brand', 'os', 'inches', 'resolution', 'battery',
#        'battery_type', 'ram(GB)', 'announcement_date', 'weight(g)',
#        'storage(GB)', 'video_720p', 'video_1080p', 'video_4K', 'video_8K',
#        'video_30fps', 'video_60fps', 'video_120fps', 'video_240fps',
#        'video_480fps', 'video_960fps', 'price(USD)'],
#       dtype='object')

# %%
plt.scatter(df['inches'],df['price(USD)'])
plt.title('Price and inches')
plt.xlabel('inches')
plt.ylabel('USD')
# Out:
# Text(0, 0.5, 'USD')

# %%
plt.scatter(df['storage(GB)'],df['price(USD)'])

# %%
df.columns
# Out:
# Index(['phone_name', 'brand', 'os', 'inches', 'resolution', 'battery',
#        'battery_type', 'ram(GB)', 'announcement_date', 'weight(g)',
#        'storage(GB)', 'video_720p', 'video_1080p', 'video_4K', 'video_8K',
#        'video_30fps', 'video_60fps', 'video_120fps', 'video_240fps',
#        'video_480fps', 'video_960fps', 'price(USD)'],
#       dtype='object')

# %%
plt.hist(df['inches'].value_counts())
# Out:
# (array([73., 15.,  5.,  2.,  2.,  0.,  1.,  0.,  0.,  1.]),
#  array([  1.,  18.,  35.,  52.,  69.,  86., 103., 120., 137., 154., 171.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['price(USD)'].value_counts())
# Out:
# (array([398.,  15.,   4.,  10.,   9.,   2.,   2.,   1.,   0.,   1.]),
#  array([ 1. ,  7.5, 14. , 20.5, 27. , 33.5, 40. , 46.5, 53. , 59.5, 66. ]),
#  <BarContainer object of 10 artists>)

# %%
df.columns
# Out:
# Index(['phone_name', 'brand', 'os', 'inches', 'resolution', 'battery',
#        'battery_type', 'ram(GB)', 'announcement_date', 'weight(g)',
#        'storage(GB)', 'video_720p', 'video_1080p', 'video_4K', 'video_8K',
#        'video_30fps', 'video_60fps', 'video_120fps', 'video_240fps',
#        'video_480fps', 'video_960fps', 'price(USD)'],
#       dtype='object')

# %%
group_ram_storage=df.groupby(['storage(GB)','ram(GB)'])['price(USD)'].mean()
group_ram_storage
# Out:
# storage(GB)  ram(GB)
# 1            24          470.000000
# 8            1           408.571429
#              2           170.000000
# 16           1           162.047500
#              2           182.758621
#              3           205.217391
#              4           262.222222
#              5           160.000000
# 32           2           224.447895
#              3           259.776633
#              4           217.667504
#              6           177.541667
#              8           220.000000
# 64           2           210.000000
#              3           215.824533
#              4           269.595322
#              6           287.626480
#              8           269.649267
# 128          4           287.616250
#              6           389.004579
#              8           367.164891
#              12          403.666667
#              16          539.823333
#              18          880.000000
# 256          6           215.000000
# ...

# %%
pivot_ram_storage=pd.pivot_table(df, index=['storage(GB)','ram(GB)'], values=['price(USD)'],aggfunc=np.mean)
pivot_ram_storage
# Out:
#                       price(USD)
# storage(GB) ram(GB)
# 1           24        470.000000
# 8           1         408.571429
#             2         170.000000
# 16          1         162.047500
#             2         182.758621
#             3         205.217391
#             4         262.222222
#             5         160.000000
# 32          2         224.447895
#             3         259.776633
#             4         217.667504
#             6         177.541667
#             8         220.000000
# 64          2         210.000000
#             3         215.824533
#             4         269.595322
#             6         287.626480
#             8         269.649267
# 128         4         287.616250
#             6         389.004579
#             8         367.164891
#             12        403.666667
#             16        539.823333
#             18        880.000000
# 256         6         215.000000
#             8         495.036891
# ...

# %%
pivot_ram_storage=pd.pivot_table(df, index=['storage(GB)'],columns=['ram(GB)'], values=['price(USD)'],aggfunc=np.mean)
pivot_ram_storage
# Out:
#              price(USD)                                             \
# ram(GB)              1           2           3           4      5
# storage(GB)
# 1                   NaN         NaN         NaN         NaN    NaN
# 8            408.571429  170.000000         NaN         NaN    NaN
# 16           162.047500  182.758621  205.217391  262.222222  160.0
# 32                  NaN  224.447895  259.776633  217.667504    NaN
# 64                  NaN  210.000000  215.824533  269.595322    NaN
# 128                 NaN         NaN         NaN  287.616250    NaN
# 256                 NaN         NaN         NaN         NaN    NaN
# 512                 NaN         NaN         NaN         NaN    NaN
#
#                                                                             \
# ram(GB)              6           8      10          12           16     18
# storage(GB)
# 1                   NaN         NaN    NaN         NaN          NaN    NaN
# ...

# %%
df.head()
# Out:
#        phone_name   brand           os  inches resolution  battery  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0   720x1280     2200
# 1        K20 plus      LG  Android 7.0     5.3   720x1280     2700
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2  1080x1920     3000
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5  1080x1920     4100
# 4             P10  Huawei  Android 7.0     5.1  1080x1920     3200
#
#   battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 0        Li-Po        2        2016-09-01      140.0  ...        False
# 1       Li-Ion        2        2016-12-01      140.0  ...         True
# 2       Li-Ion        4        2017-01-01      147.0  ...         True
# 3        Li-Po        4        2017-01-01      165.0  ...         True
# 4       Li-Ion        4        2017-02-01      145.0  ...         True
#
#    video_4K  video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# ...

# %%
df['video_960fps'][df['video_960fps']==True] =1
df['video_960fps'][df['video_960fps']==False] =0
# Out:
# <ipython-input-45-5697bdee0ef5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['video_960fps'][df['video_960fps']==True] =1

# %%
df['video_960fps'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
df['video_960fps']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1507    0
# 1508    0
# 1509    0
# 1510    0
# 1511    0
# Name: video_960fps, Length: 1512, dtype: object

# %%
df['New_video_960fps']= df['video_960fps'].map({ '1': True , '0':False})

# %%
df['New_video_960fps']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1507    NaN
# 1508    NaN
# 1509    NaN
# 1510    NaN
# 1511    NaN
# Name: New_video_960fps, Length: 1512, dtype: object

# %% [markdown]
# **Bivarianct Analysis and methods **

# %%
df.columns
# Out:
# Index(['phone_name', 'brand', 'os', 'inches', 'resolution', 'battery',
#        'battery_type', 'ram(GB)', 'announcement_date', 'weight(g)',
#        'storage(GB)', 'video_720p', 'video_1080p', 'video_4K', 'video_8K',
#        'video_30fps', 'video_60fps', 'video_120fps', 'video_240fps',
#        'video_480fps', 'video_960fps', 'price(USD)', 'New_video_960fps'],
#       dtype='object')

# %%
df['price(USD)'].var()
# Out:
# 71150.66576507087

# %%
df[['price(USD)','weight(g)']].cov()
# Out:
#               price(USD)    weight(g)
# price(USD)  71150.665765  1498.555640
# weight(g)    1498.555640   686.446018
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['price(USD)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
# ...

# %%
df[['price(USD)','inches']].corr()
# Out:
#             price(USD)    inches
# price(USD)    1.000000  0.192769
# inches        0.192769  1.000000

# %%
df[['price(USD)','ram(GB)','inches','battery']].corr()
# Out:
#             price(USD)   ram(GB)    inches   battery
# price(USD)    1.000000  0.293638  0.192769 -0.008050
# ram(GB)       0.293638  1.000000  0.533778  0.360098
# inches        0.192769  0.533778  1.000000  0.673548
# battery      -0.008050  0.360098  0.673548  1.000000

# %%
from scipy import stats
stats.norm.cdf(1.3)
# Out:
# 0.9031995154143897

# %%
df['price(USD)'].std()
# Out:
# 266.74082133237664
