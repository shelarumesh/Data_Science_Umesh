# %%
path='/content/drive/MyDrive/01 Data Science with Python ML deep learning/ML/Time Series Data/airline_passengers.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(path)
df.set_index('Month',inplace=True)
df.head()
# Out:
#          Thousands of Passengers
# Month
# 1949-01                    112.0
# 1949-02                    118.0
# 1949-03                    132.0
# 1949-04                    129.0
# 1949-05                    121.0

# %%
sns.lineplot(df['Thousands of Passengers'])
# Out:
# <Axes: xlabel='Month', ylabel='Thousands of Passengers'>

# %%
from statsmodels.tsa.stattools import adfuller
adfuller_result = adfuller(df['Thousands of Passengers'])
adfuller_result
# Out:
# (nan,
#  nan,
#  0,
#  144,
#  {'1%': -3.476597917537401,
#   '5%': -2.8818291230495543,
#   '10%': -2.5775887982253085},
#  nan)

# %%
df1 = df
df1['A'] = df['Thousands of Passengers'] - df['Thousands of Passengers'].shift(1)
df1['B'] = df['Thousands of Passengers'] - df['Thousands of Passengers'].shift(2)
df1
# Out:
#                                                     Thousands of Passengers  \
# Month
# 1949-01                                                               112.0
# 1949-02                                                               118.0
# 1949-03                                                               132.0
# 1949-04                                                               129.0
# 1949-05                                                               121.0
# ...                                                                     ...
# 1960-09                                                               508.0
# 1960-10                                                               461.0
# 1960-11                                                               390.0
# 1960-12                                                               432.0
# International airline passengers: monthly total...                      NaN
#
# ...
