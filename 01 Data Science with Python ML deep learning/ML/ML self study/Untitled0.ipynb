# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ML
#
# 1. Pre-Processing
# 2. Train_Test_Split
# 3. Modelling and Prediction
# 4. Model Evaluation
# 5. Model Selection
# 6. Optimization

# %% [markdown]
# 1. Underfitting --->
# tain accuracy < test Accuracy
# 2. Overfitting ---> tain accuracy < test Accuracy
# 3. Goode Model ---> test accuracy == predict accuracy

# %% [markdown]
# # Linear Regression:
#
# A. Simple Linear Regression
# 1. Simple Linear Regression
# 2. Simple Non Linear Regression
#
# B. Multiple Linear Regression
# 1. Multiple Linear Regression
# 2. Multiple Non Linear Regression

# %%
x=np.linspace(0,100,10)
y=2*x
len(x), len(y)
# Out:
# (10, 10)

# %%
x,y
# Out:
# (array([  0.        ,  11.11111111,  22.22222222,  33.33333333,
#          44.44444444,  55.55555556,  66.66666667,  77.77777778,
#          88.88888889, 100.        ]),
#  array([  0.        ,  22.22222222,  44.44444444,  66.66666667,
#          88.88888889, 111.11111111, 133.33333333, 155.55555556,
#         177.77777778, 200.        ]))

# %%
plt.plot(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y)
plt.title("x and y plot result in scatter plot")
plt.xlabel('x values')
plt.ylabel()
plt.show()

# %%
X=[x]
y=[y]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict(X)
# Out:
# array([[  2.        ,  12.42105263,  22.84210526,  33.26315789,
#          43.68421053,  54.10526316,  64.52631579,  74.94736842,
#          85.36842105,  95.78947368, 106.21052632, 116.63157895,
#         127.05263158, 137.47368421, 147.89473684, 158.31578947,
#         168.73684211, 179.15789474, 189.57894737, 200.        ]])
