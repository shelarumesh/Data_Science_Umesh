# %% [markdown]
# KNN Agorithm
# ---
#
# K Nearest Neighbor
# __________________
#
#
# Step 01 : Choose the number K of neighbor
#
# Step 02 : Take the K nearest neighbor of the new data point. accourding tothe Eucliden distance
#
# Step 03 : Among these K neighbors, count the number of data points in each categories
#
# Step 04 :  Assing the new data point to category
#
# finished
