# %% [markdown]
# # Data Visualization
# Data Science
#
# Matplotlib ---> basic
# Seaborn ---> Advhance
#
# Data Analytics
#
# Tablue ---> Advhance
# Power BI ---> Advhance

# %% [markdown]
# 1.   Descriptive Analysis ---> discribe data
# 2.   Diagnostic Analysis ---> reason why it happends
# 3. Predictive Analysis ---> from data predict
# 4. Prescriptive Anlysis --->
#
#
# Data Analyst (Descriptive + Diagnostic )
# -----------------
# ____________
# Goal ---> Excellent Plots
# ___
# Power BI <-------> Tablue
#
# skills ====>
# SQL --->Python (Pandas) ----> Statistics ---> Power BI/Tablue
#
# Data Scientist
# -----------------
# __________________
# Goal ---> Predict with Maximum Accuracy
# ____
# Skills ===> SQL ---> Statistics---> Python ---> Data Preprocessing ---> ML/AI ----> Cross Validation ---> Optimization ----> Present
#
# Worked flow
# Observed data (Data Exploration)
# ---> Pandas + Matplotlib + Seaborn <---
# ________
# 1. Data Cleaning
# 2. Data Transformation
# ____

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np

# %%
path='/content/drive/MyDrive/Python/Dataset/insurance_data.csv'
df=pd.read_csv(path)
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df[df['bought_insurance']==0].mean()
# Out:
# age                 27.923077
# bought_insurance     0.000000
# dtype: float64

# %%
df[df['bought_insurance']==1].mean()
# Out:
# age                 50.571429
# bought_insurance     1.000000
# dtype: float64

# %%
df.groupby('bought_insurance')['age'].mean()
# Out:
# bought_insurance
# 0    27.923077
# 1    50.571429
# Name: age, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 560.0 bytes

# %% [markdown]
# New Data frame for practice

# %%
df1=pd.read_csv('/content/drive/MyDrive/Python/Dataset/Transformed_Housing_Data.csv')
df1.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#    No of Times Visited Condition of the House  ...  \
# 0                    0                   Fair  ...
# 1                    0                   Fair  ...
# ...

# %% [markdown]
# Data Cleanning
# ----
# 1. Wrong Data
# 2.

# %%
df1.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.160900e+04  2.160900e+04    21609.000000     21609.000000
# mean   4.580686e+09  5.116186e+05        3.370771         2.114709
# std    2.876653e+09  2.500620e+05        0.929916         0.770097
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904931e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  1.129575e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# count         21609.000000        2.160900e+04  21609.000000
# mean           2079.872553        1.510641e+04      1.494215
# std             918.347816        4.142353e+04      0.539909
# min             290.000000        5.200000e+02      1.000000
# ...

# %%
df1['No of Bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Sale Price                                 21609 non-null  float64
#  2   No of Bedrooms                             21609 non-null  int64
#  3   No of Bathrooms                            21609 non-null  float64
#  4   Flat Area (in Sqft)                        21609 non-null  float64
#  5   Lot Area (in Sqft)                         21609 non-null  float64
#  6   No of Floors                               21609 non-null  float64
#  7   Waterfront View                            21609 non-null  object
#  8   No of Times Visited                        21609 non-null  int64
#  9   Condition of the House                     21609 non-null  object
# ...

# %% [markdown]
# Wrong data
# -----
# Solution : replace data
# - Collect data
# - Statistical
# - Reaserch
# - Comman sence

# %%
df1['Ever Renovated'] = df1['Ever Renovated'].astype('str')

# %%
df1['Ever Renovated'].duplicated().sum()
# Out:
# 21607

# %%
df1['Ever Renovated'].value_counts()
# Out:
# No     20695
# Yes      914
# Name: Ever Renovated, dtype: int64

# %%
plt.bar(['Y', 'N'], df1['Ever Renovated'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 560.0 bytes

# %%
plt.hist(df['age'],bins=8)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('histogram of age')
#plt.text('bins')
plt.show()

# %%
plt.hist(df['bought_insurance'],bins=8)
plt.xlabel('insurance')
plt.ylabel('Frequency')
plt.title('histogram of insurance')
plt.show()

# %%
df['age'].skew()
# Out:
# -0.05311895888194786

# %%
plt.boxplot(df['age'])
plt.title('boxplot of age')
plt.show()

# %%
plt.scatter(df['age'],df['bought_insurance'])

# %%
df[['age','bought_insurance']].cov()
# Out:
#                          age  bought_insurance
# age               247.923077          5.871795
# bought_insurance    5.871795          0.259259

# %%
df[['age','bought_insurance']].corr()
# Out:
#                        age  bought_insurance
# age               1.000000          0.732395
# bought_insurance  0.732395          1.000000

# %%
df.corr()
# Out:
#                        age  bought_insurance
# age               1.000000          0.732395
# bought_insurance  0.732395          1.000000

# %%
plt.plot(df, marker='*',linewidth=0.5)

# %%
plt.plot(df['age'])

# %%
plt.plot(df['bought_insurance'])

# %%
x=np.arange(6)
y=x
z=x**1.5

# %%
plt.plot(x,y, label='Linear')
plt.plot(x,z, label='quadratic')
#plt.xlabel('x value')
plt.legend()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Sale Price                                 21609 non-null  float64
#  2   No of Bedrooms                             21609 non-null  int64
#  3   No of Bathrooms                            21609 non-null  float64
#  4   Flat Area (in Sqft)                        21609 non-null  float64
#  5   Lot Area (in Sqft)                         21609 non-null  float64
#  6   No of Floors                               21609 non-null  float64
#  7   Waterfront View                            21609 non-null  object
#  8   No of Times Visited                        21609 non-null  int64
#  9   Condition of the House                     21609 non-null  object
# ...

# %%
plt.pie(df1['Waterfront View'].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x7dec29c59d80>,
# ...
#  [Text(-1.0996911502824303, 0.02606480367287548, ''),
#   Text(1.0996911508162595, -0.026064781150262797, '')])

# %%
plt.pie([6,9], labels=['Male', 'Female'], counterclock=False,explode=[0,0.2])
plt.show()

# %%
plt.pie([6,9,12,3,10],autopct='%0.1f%%', labels=['Male', 'Female',"hi", 'Bi','G'], counterclock=False,explode=[0,0.01,0,0,0.1])
plt.show()

# %%
plt.bar(df1['Ever Renovated'].value_counts().index,len(df1['Ever Renovated']))
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(df1['Ever Renovated'].value_counts().index,df1['Ever Renovated'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
df1['Ever Renovated'].describe()
# Out:
# count     21609
# unique        2
# top          No
# freq      20695
# Name: Ever Renovated, dtype: object

# %%
df1['Ever Renovated'].value_counts()
# Out:
# No     20695
# Yes      914
# Name: Ever Renovated, dtype: int64

# %%
plt.barh(df1['Ever Renovated'].value_counts().index,df1['Ever Renovated'].value_counts())
# Out:
# <BarContainer object of 2 artists>
