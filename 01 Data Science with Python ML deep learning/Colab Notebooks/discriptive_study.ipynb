# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path='/content/drive/MyDrive/Python/Dataset/EDA_Housing_Prices.csv'
df=pd.read_csv(path)
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Date House was Sold', 'Sale Price', 'No of Bedrooms',
#        'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)',
#        'No of Floors', 'Waterfront View', 'No of Times Visited',
#        'Condition of the House', 'Overall Grade',
#        'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)',
#        'Age of House (in Years)', 'Renovated Year', 'Zipcode', 'Latitude',
#        'Longitude', 'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
df['Sale Price'].corr(df['Lot Area (in Sqft)'])
# Out:
# 0.08961576750095164

# %%
df.drop(columns=['ID'],axis=1).corr()
# Out:
# <ipython-input-13-328c12d723e9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.drop(columns=['ID'],axis=1).corr()
#                                            Sale Price  No of Bedrooms  \
# Sale Price                                   1.000000        0.308463
# No of Bedrooms                               0.308463        1.000000
# No of Bathrooms                              0.525124        0.515883
# Flat Area (in Sqft)                          0.702081        0.576616
# Lot Area (in Sqft)                           0.089616        0.031620
# No of Floors                                 0.256941        0.175429
# Overall Grade                                0.580654        0.349008
# Area of the House from Basement (in Sqft)    0.605495        0.477592
# ...

# %% [markdown]
# Dscreaptive Analysis for Univariant

# %%
df['Sale Price'].head(10)
# Out:
# 0     221900.0
# 1     538000.0
# 2     180000.0
# 3     604000.0
# 4     510000.0
# 5    1230000.0
# 6     257500.0
# 7     291850.0
# 8     229500.0
# 9     323000.0
# Name: Sale Price, dtype: float64

# %%
df['Sale Price'].tail(10)
# Out:
# 21603     507250.0
# 21604     429000.0
# 21605     610685.0
# 21606    1010000.0
# 21607     475000.0
# 21608     360000.0
# 21609     400000.0
# 21610     402101.0
# 21611     400000.0
# 21612     325000.0
# Name: Sale Price, dtype: float64

# %%
df['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %%
plt.hist(df['Sale Price'])
# Out:
# (array([1.9017e+04, 2.1420e+03, 3.2200e+02, 9.0000e+01, 2.6000e+01,
#         4.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  75000.,  837500., 1600000., 2362500., 3125000., 3887500.,
#         4650000., 5412500., 6175000., 6937500., 7700000.]),
#  <BarContainer object of 10 artists>)

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
df.drop(columns = ['ID'], inplace = True)

# %%
df.columns
# Out:
# Index(['Date House was Sold', 'Sale Price', 'No of Bedrooms',
#        'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)',
#        'No of Floors', 'Waterfront View', 'No of Times Visited',
#        'Condition of the House', 'Overall Grade',
#        'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)',
#        'Age of House (in Years)', 'Renovated Year', 'Zipcode', 'Latitude',
#        'Longitude', 'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
df['Condition of the House'].value_counts()
# Out:
# Fair         14031
# Good          5679
# Excellent     1701
# Okay           172
# Bad             30
# Name: Condition of the House, dtype: int64

# %%
df['Condition of the House'].head()
# Out:
# 0         Fair
# 1         Fair
# 2         Fair
# 3    Excellent
# 4         Fair
# Name: Condition of the House, dtype: object

# %%
plt.scatter(df['Condition of the House'],df['Sale Price'])

# %%
df.groupby('Condition of the House')['Sale Price'].mean().plot(kind='bar',color=['green','red','blue','red','black'])
# Out:
# <Axes: xlabel='Condition of the House'>

# %%
df.groupby('Waterfront View')['Sale Price'].mean().sort_values().plot(kind='bar',color=['green','red','blue','red','black'])
# Out:
# <Axes: xlabel='Waterfront View'>

# %%
df.groupby('Zipcode')['Sale Price'].mean().sort_values().plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='Zipcode'>

# %% [markdown]
# # **Anova -  relation bet numerical target variable and categorical values**

# %% [markdown]
# 1.   Null Hypothesis ---> no deff in mean
# 2.   Alternate Hypothesis ---> at list one diff of the mean
#
#
#       One way and two way

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
df=df.rename(columns=())
